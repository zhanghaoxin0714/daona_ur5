# %%
from UR5 import UR5_model

robot = UR5_model()

# %%
base_jacobian = robot.getBaseJocobian()
base_jacobian
# Out:
# array([[-1.91450000e-01, -9.46500000e-02, -9.46500000e-02,
#         -9.46500000e-02,  8.23000000e-02,  0.00000000e+00],
#        [ 8.17250000e-01, -7.70371978e-34,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 3.08148791e-33, -8.17250000e-01, -3.92250000e-01,
#         -1.15912820e-17,  1.00788432e-17,  0.00000000e+00],
#        [ 0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00,  1.22464680e-16,  0.00000000e+00],
#        [ 0.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  1.00000000e+00],
#        [ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -1.00000000e+00,  0.00000000e+00]])

# %%
robot.updateStatus([0, 0, 0, 0, 0, 1])
base_jacobian = robot.getBaseJocobian()
base_jacobian
# Out:
# array([[-1.91450000e-01, -9.46500000e-02, -9.46500000e-02,
#         -9.46500000e-02,  8.23000000e-02,  0.00000000e+00],
#        [ 8.17250000e-01,  0.00000000e+00,  0.00000000e+00,
#          3.85185989e-34,  0.00000000e+00,  0.00000000e+00],
#        [-1.38777878e-17, -8.17250000e-01, -3.92250000e-01,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00, -1.23259516e-32, -1.23259516e-32,
#         -1.23259516e-32,  0.00000000e+00, -1.23259516e-32],
#        [ 0.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  1.00000000e+00],
#        [ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -1.00000000e+00,  0.00000000e+00]])

# %%
base_jacobian = robot.getBaseJocobianWith_q([0, 0, 0, 0, 0, 1])
base_jacobian
# Out:
# array([[-1.91450000e-01, -9.46500000e-02, -9.46500000e-02,
#         -9.46500000e-02,  8.23000000e-02,  0.00000000e+00],
#        [ 8.17250000e-01,  0.00000000e+00,  0.00000000e+00,
#          3.85185989e-34,  0.00000000e+00,  0.00000000e+00],
#        [-1.38777878e-17, -8.17250000e-01, -3.92250000e-01,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#        [ 0.00000000e+00, -1.23259516e-32, -1.23259516e-32,
#         -1.23259516e-32,  0.00000000e+00, -1.23259516e-32],
#        [ 0.00000000e+00,  1.00000000e+00,  1.00000000e+00,
#          1.00000000e+00,  0.00000000e+00,  1.00000000e+00],
#        [ 1.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -1.00000000e+00,  0.00000000e+00]])
